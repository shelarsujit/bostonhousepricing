# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_boston

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
dataset=pd.DataFrame(data,columns=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT'])
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
price=pd.DataFrame(target,columns=['Price'])
dataset['Price']=price

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       Price
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# Price   -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT     Price
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# Price    0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
import seaborn as sns
sns.pairplot(dataset)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# d:\Sujit\Data-Science-Projects\bostonhousepricing\Boston-housing.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Sujit/Data-Science-Projects/bostonhousepricing/Boston-housing.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> import seaborn as sns
# ----> <a href='vscode-notebook-cell:/d%3A/Sujit/Data-Science-Projects/bostonhousepricing/Boston-housing.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> sns.pairplot(dataset)
#
# File d:\Sujit\Data-Science-Projects\bostonhousepricing\venv\lib\site-packages\seaborn\axisgrid.py:2144, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2142 diag_kws.setdefault("legend", False)
#    2143 if diag_kind == "hist":
# -> 2144     grid.map_diag(histplot, **diag_kws)
#    2145 elif diag_kind == "kde":
#    2146     diag_kws.setdefault("fill", True)
#
# File d:\Sujit\Data-Science-Projects\bostonhousepricing\venv\lib\site-packages\seaborn\axisgrid.py:1507, in PairGrid.map_diag(self, func, **kwargs)
#    1505     plot_kwargs.setdefault("hue_order", self._hue_order)
#    1506     plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1507     func(x=vector, **plot_kwargs)
#    1508     ax.legend_ = None
#    1510 self._add_axis_labels()
#
# File d:\Sujit\Data-Science-Projects\bostonhousepricing\venv\lib\site-packages\seaborn\distributions.py:1418, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1416     else:
#    1417         method = ax.plot
# -> 1418     color = _default_color(method, hue, color, kwargs)
#    1420 if not p.has_xy_data:
#    1421     return ax
#
# File d:\Sujit\Data-Science-Projects\bostonhousepricing\venv\lib\site-packages\seaborn\utils.py:139, in _default_color(method, hue, color, kws)
#     134     scout.remove()
#     136 elif method.__name__ == "bar":
#     137
#     138     # bar() needs masked, not empty data, to generate a patch
# --> 139     scout, = method([np.nan], [np.nan], **kws)
#     140     color = to_rgb(scout.get_facecolor())
#     141     scout.remove()
#
# File d:\Sujit\Data-Science-Projects\bostonhousepricing\venv\lib\site-packages\matplotlib\__init__.py:1423, in inner(ax, data, *args, **kwargs)
#    1421         if replace_names is None or k1 in replace_names:
#    1422             v[k1] = _replacer(data, v1)
# -> 1423 elif k == varargs_name:
#    1424     if replace_names is None:
#    1425         bound.arguments[k] = tuple(_replacer(data, v1) for v1 in v)
#
# File d:\Sujit\Data-Science-Projects\bostonhousepricing\venv\lib\site-packages\matplotlib\axes\_axes.py:2373, in bar(self, x, height, width, bottom, align, **kwargs)
#    2371 if orientation == 'vertical':
#    2372     try:
# -> 2373         left = x - width / 2
#    2374     except TypeError as e:
#    2375         raise TypeError(f'the dtypes of parameters x ({x.dtype}) '
#    2376                         f'and width ({width.dtype}) '
#    2377                         f'are incompatible') from e
#
# File d:\Sujit\Data-Science-Projects\bostonhousepricing\venv\lib\site-packages\matplotlib\axes\_axes.py:2182, in _convert_dx(dx, x0, xconv, convert)
#    2171 @_preprocess_data()
#    2172 @docstring.dedent_interpd
#    2173 def bar(self, x, height, width=0.8, bottom=None, *, align="center",
#    2174         **kwargs):
#    2175     r"""
#    2176     Make a bar plot.
#    2177
#    2178     The bars are positioned at *x* with the given *align*\ment. Their
#    2179     dimensions are given by *height* and *width*. The vertical baseline
#    2180     is *bottom* (default 0).
#    2181
# -> 2182     Many parameters can take either a single value applying to all bars
#    2183     or a sequence of values, one for each bar.
#    2184
#    2185     Parameters
#    2186     ----------
#    2187     x : float or array-like
#    2188         The x coordinates of the bars. See also *align* for the
#    2189         alignment of the bars to the coordinates.
#    2190
#    2191     height : float or array-like
#    2192         The height(s) of the bars.
#    2193
#    2194     width : float or array-like, default: 0.8
#    2195         The width(s) of the bars.
#    2196
#    2197     bottom : float or array-like, default: 0
#    2198         The y coordinate(s) of the bars bases.
#    2199
#    2200     align : {'center', 'edge'}, default: 'center'
#    2201         Alignment of the bars to the *x* coordinates:
#    2202
#    2203         - 'center': Center the base on the *x* positions.
#    2204         - 'edge': Align the left edges of the bars with the *x* positions.
#    2205
#    2206         To align the bars on the right edge pass a negative *width* and
#    2207         ``align='edge'``.
#    2208
#    2209     Returns
#    2210     -------
#    2211     `.BarContainer`
#    2212         Container with all the bars and optionally errorbars.
#    2213
#    2214     Other Parameters
#    2215     ----------------
#    2216     color : color or list of color, optional
#    2217         The colors of the bar faces.
#    2218
#    2219     edgecolor : color or list of color, optional
#    2220         The colors of the bar edges.
#    2221
#    2222     linewidth : float or array-like, optional
#    2223         Width of the bar edge(s). If 0, don't draw edges.
#    2224
#    2225     tick_label : str or list of str, optional
#    2226         The tick labels of the bars.
#    2227         Default: None (Use default numeric labels.)
#    2228
#    2229     xerr, yerr : float or array-like of shape(N,) or shape(2, N), optional
#    2230         If not *None*, add horizontal / vertical errorbars to the bar tips.
#    2231         The values are +/- sizes relative to the data:
#    2232
#    2233         - scalar: symmetric +/- values for all bars
#    2234         - shape(N,): symmetric +/- values for each bar
#    2235         - shape(2, N): Separate - and + values for each bar. First row
#    2236           contains the lower errors, the second row contains the upper
#    2237           errors.
#    2238         - *None*: No errorbar. (Default)
#    2239
#    2240         See :doc:`/gallery/statistics/errorbar_features`
#    2241         for an example on the usage of ``xerr`` and ``yerr``.
#    2242
#    2243     ecolor : color or list of color, default: 'black'
#    2244         The line color of the errorbars.
#    2245
#    2246     capsize : float, default: :rc:`errorbar.capsize`
#    2247        The length of the error bar caps in points.
#    2248
#    2249     error_kw : dict, optional
#    2250         Dictionary of kwargs to be passed to the `~.Axes.errorbar`
#    2251         method. Values of *ecolor* or *capsize* defined here take
#    2252         precedence over the independent kwargs.
#    2253
#    2254     log : bool, default: False
#    2255         If *True*, set the y-axis to be log scale.
#    2256
#    2257     data : indexable object, optional
#    2258         DATA_PARAMETER_PLACEHOLDER
#    2259
#    2260     **kwargs : `.Rectangle` properties
#    2261
#    2262     %(Rectangle:kwdoc)s
#    2263
#    2264     See Also
#    2265     --------
#    2266     barh : Plot a horizontal bar plot.
#    2267
#    2268     Notes
#    2269     -----
#    2270     Stacked bars can be achieved by passing individual *bottom* values per
#    2271     bar. See :doc:`/gallery/lines_bars_and_markers/bar_stacked`.
#    2272     """
#    2273     kwargs = cbook.normalize_kwargs(kwargs, mpatches.Patch)
#    2274     color = kwargs.pop('color', None)
#
# File d:\Sujit\Data-Science-Projects\bostonhousepricing\venv\lib\site-packages\matplotlib\cbook\__init__.py:1749, in _safe_first_finite(obj, skip_nonfinite)
#    1744     finally:
#    1745         lock_path.unlink()
#    1748 def _topmost_artist(
# -> 1749         artists,
#    1750         _cached_max=functools.partial(max, key=operator.attrgetter("zorder"))):
#    1751     """
#    1752     Get the topmost artist of a list.
#    1753
#    (...)
#    1756     ties, so we need to iterate over the list in reverse order.
#    1757     """
#    1758     return _cached_max(reversed(artists))
#
# StopIteration:

# %%
sns.regplot(x="RM",y="Price",data=dataset)
# Out:
# <AxesSubplot: xlabel='RM', ylabel='Price'>

# %%
sns.heatmap(dataset.corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot: >

# %%
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.head()
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 5     0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622   3.0  222.0
# 116   0.13158  0.0  10.01   0.0  0.547  6.176  72.5  2.7301   6.0  432.0
# 45    0.17142  0.0   6.91   0.0  0.448  5.682  33.8  5.1004   3.0  233.0
# 16    1.05393  0.0   8.14   0.0  0.538  5.935  29.3  4.4986   4.0  307.0
# 468  15.57570  0.0  18.10   0.0  0.580  5.926  71.0  2.9084  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# 45      17.9  396.90  10.21
# 16      21.0  386.85   6.58
# 468     20.2  368.74  18.13

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 173  0.09178   0.0   4.05   0.0  0.510  6.416   84.1  2.6463   5.0  296.0
# 274  0.05644  40.0   6.41   1.0  0.447  6.758   32.9  4.0776   4.0  254.0
# 491  0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681   4.0  711.0
# 72   0.09164   0.0  10.81   0.0  0.413  6.065    7.8  5.2873   4.0  305.0
# 452  5.09017   0.0  18.10   0.0  0.713  6.297   91.8  2.3682  24.0  666.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 441  9.72418   0.0  18.10   0.0  0.740  6.406   97.2  2.0651  24.0  666.0
# 23   0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952   4.0  307.0
# 225  0.52693   0.0   6.20   0.0  0.504  8.725   83.0  2.8944   8.0  307.0
# 433  5.58107   0.0  18.10   0.0  0.713  6.436   87.9  2.3158  24.0  666.0
# 447  9.92485   0.0  18.10   0.0  0.740  6.251   96.6  2.1980  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 173     16.6  395.50   9.04
# 274     17.6  396.90   3.53
# 491     20.1  390.11  18.07
# 72      19.2  390.91   5.52
# 452     20.2  385.09  17.27
# ..       ...     ...    ...
# 441     20.2  385.96  19.52
# 23      21.0  394.54  19.88
# 225     17.4  382.00   4.63
# 433     20.2  100.19  16.22
# 447     20.2  388.52  16.44
#
# [152 rows x 13 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_test
# Out:
# array([[-0.41814319, -0.45257245, -1.06299571, ..., -1.2129824 ,
#          0.45712276, -0.5785895 ],
#        [-0.42197518,  1.15375592, -0.70943587, ..., -0.67841202,
#          0.47107234, -1.34619278],
#        [-0.41662948, -0.45257245,  2.48608589, ...,  0.65801394,
#          0.40341687,  0.67938829],
#        ...,
#        [-0.37095894, -0.45257245, -0.74089671, ..., -0.78532609,
#          0.32260895, -1.19295074],
#        [ 0.17707231, -0.45257245,  1.04188384, ...,  0.71147097,
#         -2.48534188,  0.42166305],
#        [ 0.64807771, -0.45257245,  1.04188384, ...,  0.71147097,
#          0.38757414,  0.45231146]])

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Print the Coeff

# %%
print(reg.coef_)
# Out:
# [-1.10834602  0.80843998  0.34313466  0.81386426 -1.79804295  2.913858
#  -0.29893918 -2.94251148  2.09419303 -1.44706731 -2.05232232  1.02375187
#  -3.88579002]

# %%
print(reg.intercept_)
# Out:
# 23.01581920903955

# %% [markdown]
# ## Parameters on which model is trained

# %%
reg.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %% [markdown]
# ## Prediction on test data

# %%
reg_pred=reg.predict(X_test)

# %%
reg_pred
# Out:
# array([30.77834822, 38.66581541, 16.96705276, 26.79035818, 20.36068008,
#        24.89386356, 18.98948959, 15.44554414, 24.50205701, 22.12455513,
#        27.16709892, 20.60218969, -4.91312377, 23.45520373, 20.44300739,
#        27.97454642, 21.82481134,  6.80793603, 43.13876668, 19.08804672,
#        28.93737925, 31.91943808, 12.05148619, 25.41493356, 19.60614164,
#        17.23543021, 24.61263361, 16.907528  , 24.25623469, 20.73183868,
#        23.98650325, 26.66317526, 27.45468242, 19.57475267, 18.15660164,
#        19.94422395, 33.04896681, 21.26475982, 25.83570427, 26.36436267,
#        15.22545112, 33.61610719, 45.24385042, 18.83620774, 28.91584593,
#        18.49470905, 14.91054896, 27.65199578, 21.75498681, 32.36964545,
#        23.36168054, 36.5955736 , 16.82098601, 27.59874838, 42.39261672,
#        24.39945725, 20.42785358, 34.46608842, 26.52068304, 14.0304141 ,
#        24.03170468, 32.40960974, 33.59067192, 17.33583061, 22.46180876,
#        18.28308242, 22.01801285, 27.57486429, 32.54366102, 13.95067422,
#        21.96577449, 29.21079363, 12.65101384, 17.15704754, 25.56951945,
#         6.99478235, 22.73334313, 43.93983367, 20.03571324, 10.919632  ,
#        22.50309934, 14.46771561, 23.07376266, 10.52688537, 24.71136556,
#        34.38262811, 21.02382869, 27.04400189, 30.94450114, 21.54068028,
#        27.48732329,  7.31708375, 21.56254771, 16.57285469, 14.43338806,
#        22.26113509, 26.42907376,  1.28686278, 15.98179144, 18.13930581,
#        23.62097091, 26.3208465 , 12.12867204, 20.66733158, 25.32719152,
#        14.23008516, 19.48076211, 26.9289352 , 22.02461937, 26.11181168,
#         9.83654844, 21.30376854, 23.13155127, 28.99045653, 34.46072055,
#        17.31422502, 36.81803955, 14.0639201 , 22.38719669, 30.47720506,
#        16.96724187, 26.23079837,  6.30719991, 25.6891189 , 27.44337177,
#        24.41723783, 26.72754089, 35.52652858, 23.8342233 , 41.30725508,
#        15.51580837, 27.19720138, 18.99437335, 22.50080685, 11.95557604,
#        23.13463621, 23.4954008 , 34.27666272, 33.53948706, 16.55984176,
#        17.98511069, 31.00757978, 26.51337445, 18.4765867 ,  7.99167823,
#        28.32517448, 26.1665569 , 19.032183  , 14.47502635, 42.88762567,
#        18.69947012, 19.82530166])

# %% [markdown]
# ## Scatter for pred

# %%
plt.scatter(reg_pred,y_test)

# %%
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 173   -7.178348
# 274   -6.265815
# 491   -3.367053
# 72    -3.990358
# 452   -4.260680
#          ...
# 441   -1.932183
# 23     0.024974
# 225    7.112374
# 433   -4.399470
# 447   -7.225302
# Name: Price, Length: 152, dtype: float64

# %% [markdown]
# ## Plotting this residuals

# %%
sns.displot(residuals,kind='kde')

# %%
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 24.13479128906756
# 3.744212793154547
# 4.912717301969202

# %% [markdown]
# ## R Square and Adjusted R square

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.6761000049033605

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6455876865246917

# %% [markdown]
# ## New data prediction

# %%
X_t=X_test[0].reshape(1,-1)

# %%
reg.predict(X_t)
# Out:
# array([30.77834822])

# %%
import pickle

# %%
pickle.dump(reg,open('regmodel.pkl','wb'))

# %%
pickle_model=pickle.load(open('regmodel.pkl','rb'))

# %%
pickle_model.predict(X_t)
# Out:
# array([30.77834822])
